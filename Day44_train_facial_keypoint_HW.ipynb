# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
import tensorflow as tf
print(tf.__version__)

import os
from google.colab import drive 
drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# %cd 'facial-keypoints-detection'
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2`. This will be interpreted as: `1.x`.
#
#
# TensorFlow 1.x selected.
# 1.15.2
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# /content/gdrive/My Drive
# /content/gdrive/My Drive/facial-keypoints-detection

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
# 印出網路結構
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=50, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 1712 samples, validate on 428 samples
# Epoch 1/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0078 - val_loss: 0.0024
#
# Epoch 00001: val_loss improved from inf to 0.00245, saving model to best_weights.h5
# Epoch 2/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0019 - val_loss: 0.0018
#
# Epoch 00002: val_loss improved from 0.00245 to 0.00184, saving model to best_weights.h5
# Epoch 3/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0014 - val_loss: 0.0019
#
# Epoch 00003: val_loss did not improve from 0.00184
# Epoch 4/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0012 - val_loss: 0.0018
#
# Epoch 00004: val_loss improved from 0.00184 to 0.00184, saving model to best_weights.h5
# Epoch 5/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0011 - val_loss: 0.0019
#
# Epoch 00005: val_loss did not improve from 0.00184
# Epoch 6/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0011 - val_loss: 0.0018
#
# Epoch 00006: val_loss did not improve from 0.00184
# Epoch 7/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.4213e-04 - val_loss: 0.0017
#
# Epoch 00007: val_loss improved from 0.00184 to 0.00168, saving model to best_weights.h5
# Epoch 8/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 8.0282e-04 - val_loss: 0.0015
#
# Epoch 00008: val_loss improved from 0.00168 to 0.00150, saving model to best_weights.h5
# Epoch 9/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 6.9936e-04 - val_loss: 0.0014
#
# Epoch 00009: val_loss improved from 0.00150 to 0.00139, saving model to best_weights.h5
# Epoch 10/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 6.1719e-04 - val_loss: 0.0013
#
# Epoch 00010: val_loss improved from 0.00139 to 0.00126, saving model to best_weights.h5
# Epoch 11/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 5.6993e-04 - val_loss: 0.0012
#
# Epoch 00011: val_loss improved from 0.00126 to 0.00116, saving model to best_weights.h5
# Epoch 12/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 5.2071e-04 - val_loss: 0.0011
#
# Epoch 00012: val_loss improved from 0.00116 to 0.00111, saving model to best_weights.h5
# Epoch 13/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 4.8004e-04 - val_loss: 0.0011
#
# Epoch 00013: val_loss did not improve from 0.00111
# Epoch 14/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 4.4816e-04 - val_loss: 0.0010
#
# Epoch 00014: val_loss improved from 0.00111 to 0.00105, saving model to best_weights.h5
# Epoch 15/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 4.3281e-04 - val_loss: 0.0010
#
# Epoch 00015: val_loss improved from 0.00105 to 0.00104, saving model to best_weights.h5
# Epoch 16/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 4.0254e-04 - val_loss: 9.4693e-04
#
# Epoch 00016: val_loss improved from 0.00104 to 0.00095, saving model to best_weights.h5
# Epoch 17/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.7634e-04 - val_loss: 9.8551e-04
#
# Epoch 00017: val_loss did not improve from 0.00095
# Epoch 18/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.6165e-04 - val_loss: 9.1978e-04
#
# Epoch 00018: val_loss improved from 0.00095 to 0.00092, saving model to best_weights.h5
# Epoch 19/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.5561e-04 - val_loss: 9.2159e-04
#
# Epoch 00019: val_loss did not improve from 0.00092
# Epoch 20/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.4770e-04 - val_loss: 8.5830e-04
#
# Epoch 00020: val_loss improved from 0.00092 to 0.00086, saving model to best_weights.h5
# Epoch 21/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.2562e-04 - val_loss: 8.4470e-04
#
# Epoch 00021: val_loss improved from 0.00086 to 0.00084, saving model to best_weights.h5
# Epoch 22/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.1428e-04 - val_loss: 8.4228e-04
#
# Epoch 00022: val_loss improved from 0.00084 to 0.00084, saving model to best_weights.h5
# Epoch 23/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.0478e-04 - val_loss: 9.0340e-04
#
# Epoch 00023: val_loss did not improve from 0.00084
# Epoch 24/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.0142e-04 - val_loss: 8.1470e-04
#
# Epoch 00024: val_loss improved from 0.00084 to 0.00081, saving model to best_weights.h5
# Epoch 25/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.8532e-04 - val_loss: 8.3953e-04
#
# Epoch 00025: val_loss did not improve from 0.00081
# Epoch 26/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.7972e-04 - val_loss: 8.0499e-04
#
# Epoch 00026: val_loss improved from 0.00081 to 0.00080, saving model to best_weights.h5
# Epoch 27/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.7296e-04 - val_loss: 8.1261e-04
#
# Epoch 00027: val_loss did not improve from 0.00080
# Epoch 28/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.6878e-04 - val_loss: 8.2951e-04
#
# Epoch 00028: val_loss did not improve from 0.00080
# Epoch 29/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.7166e-04 - val_loss: 8.6578e-04
#
# Epoch 00029: val_loss did not improve from 0.00080
# Epoch 30/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.5438e-04 - val_loss: 8.2310e-04
#
# Epoch 00030: val_loss did not improve from 0.00080
# Epoch 31/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.4791e-04 - val_loss: 8.0834e-04
#
# Epoch 00031: val_loss did not improve from 0.00080
# Epoch 32/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.4958e-04 - val_loss: 7.5185e-04
#
# Epoch 00032: val_loss improved from 0.00080 to 0.00075, saving model to best_weights.h5
# Epoch 33/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.4030e-04 - val_loss: 7.7351e-04
#
# Epoch 00033: val_loss did not improve from 0.00075
# Epoch 34/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.4664e-04 - val_loss: 7.6884e-04
#
# Epoch 00034: val_loss did not improve from 0.00075
# Epoch 35/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.3573e-04 - val_loss: 8.0887e-04
#
# Epoch 00035: val_loss did not improve from 0.00075
# Epoch 36/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.3391e-04 - val_loss: 7.5946e-04
#
# Epoch 00036: val_loss did not improve from 0.00075
# Epoch 37/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.2344e-04 - val_loss: 7.5160e-04
#
# Epoch 00037: val_loss improved from 0.00075 to 0.00075, saving model to best_weights.h5
# Epoch 38/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.1643e-04 - val_loss: 7.7399e-04
#
# Epoch 00038: val_loss did not improve from 0.00075
# Epoch 39/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.1483e-04 - val_loss: 7.4759e-04
#
# Epoch 00039: val_loss improved from 0.00075 to 0.00075, saving model to best_weights.h5
# Epoch 40/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.1536e-04 - val_loss: 7.5595e-04
#
# Epoch 00040: val_loss did not improve from 0.00075
# Epoch 41/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.1245e-04 - val_loss: 7.8594e-04
#
# Epoch 00041: val_loss did not improve from 0.00075
# Epoch 42/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.0401e-04 - val_loss: 7.3825e-04
#
# Epoch 00042: val_loss improved from 0.00075 to 0.00074, saving model to best_weights.h5
# Epoch 43/50
# 1712/1712 [==============================] - 17s 10ms/step - loss: 2.0350e-04 - val_loss: 7.6107e-04
#
# Epoch 00043: val_loss did not improve from 0.00074
# Epoch 44/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.0288e-04 - val_loss: 7.3717e-04
#
# Epoch 00044: val_loss improved from 0.00074 to 0.00074, saving model to best_weights.h5
# Epoch 45/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.9872e-04 - val_loss: 7.6645e-04
#
# Epoch 00045: val_loss did not improve from 0.00074
# Epoch 46/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.9882e-04 - val_loss: 7.7296e-04
#
# Epoch 00046: val_loss did not improve from 0.00074
# Epoch 47/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.9649e-04 - val_loss: 7.3089e-04
#
# Epoch 00047: val_loss improved from 0.00074 to 0.00073, saving model to best_weights.h5
# Epoch 48/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.9415e-04 - val_loss: 7.5659e-04
#
# Epoch 00048: val_loss did not improve from 0.00073
# Epoch 49/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.9190e-04 - val_loss: 7.7519e-04
#
# Epoch 00049: val_loss did not improve from 0.00073
# Epoch 50/50
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.8807e-04 - val_loss: 7.4464e-04
#
# Epoch 00050: val_loss did not improve from 0.00073

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 實現圖片以及關機點 label 做左右翻轉的函數
def augment_data(img, points):
    rows, cols = img.shape
    new_img = np.copy(img)
    
    # 翻轉圖片
    for i in range(96):
        for j in range(48):
            temp = img[i][j]
            new_img[i][j] = img[i][cols-j-1]
            new_img[i][cols-j-1] = temp
            
    # 翻轉關鍵點 label
    new_points = np.copy(points)
    for i in range(0,30,2):
        new_points[i] = -points[i]
    
    # 調整對稱的 label
    new_points_temp = np.copy(new_points)
    new_points[0:2] = new_points_temp[2:4]
    new_points[2:4] = new_points_temp[0:2]
    new_points[4:6] = new_points_temp[8:10]
    new_points[6:8] = new_points_temp[10:12]
    new_points[8:10] = new_points_temp[4:6]
    new_points[10:12] = new_points_temp[6:8]
    new_points[12:14] = new_points_temp[16:18]
    new_points[14:16] = new_points_temp[18:20]
    new_points[16:18] = new_points_temp[12:14]
    new_points[18:20] = new_points_temp[14:16]
    new_points[22:24] = new_points_temp[24:26]
    new_points[24:26] = new_points_temp[22:24]
        
    return new_img, new_points

# %%
flip_img, flip_points = augment_data(imgs_train[0], points_train[0])

fig = plt.figure()
ax = fig.add_subplot(1, 2, 1, xticks=[], yticks=[])
plot_keypoints(imgs_train[0], points_train[0]) # 原來的圖片
ax = fig.add_subplot(1, 2, 2, xticks=[], yticks=[])
plot_keypoints(flip_img, flip_points) # 翻轉後的圖片

# %%
# 創建 list
aug_imgs_train = []
aug_points_train = []

# 對所有原始資料做 augmentation
for i in range(imgs_train.shape[0]):
    # 做左右翻轉
    aug_img, aug_point = augment_data(imgs_train[i], points_train[i])
    
    # append 原始資料
    aug_imgs_train.append(imgs_train[i])
    aug_points_train.append(points_train[i]) 
    
    # append 做過 augmentation 後的資料
    aug_imgs_train.append(aug_img)
    aug_points_train.append(aug_point) 

# convert to numpy
aug_imgs_train = np.array(aug_imgs_train)   
aug_points_train = np.copy(aug_points_train)

print(aug_imgs_train.shape)
print(aug_points_train.shape)
# Out:
# (4280, 96, 96)
# (4280, 30)

# %%
# model checkpoint 
checkpoint_aug = ModelCheckpoint('best_weights_augment.h5', verbose=1, save_best_only=True)
# training the model
hist_model_aug = model_with_augment.fit(aug_imgs_train.reshape(aug_imgs_train.shape[0], 96, 96, 1), aug_points_train, 
                           validation_split=0.2, batch_size=64, callbacks=[checkpoint_aug, hist],
                           shuffle=True, epochs=50, verbose=1)
# Out:
# Train on 3424 samples, validate on 856 samples
# Epoch 1/50
# 3424/3424 [==============================] - 28s 8ms/step - loss: 0.0044 - val_loss: 0.0020
#
# Epoch 00001: val_loss improved from inf to 0.00198, saving model to best_weights_augment.h5
# Epoch 2/50
# 3424/3424 [==============================] - 28s 8ms/step - loss: 0.0013 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00198 to 0.00188, saving model to best_weights_augment.h5
# Epoch 3/50
# 3424/3424 [==============================] - 28s 8ms/step - loss: 0.0011 - val_loss: 0.0018
#
# Epoch 00003: val_loss improved from 0.00188 to 0.00178, saving model to best_weights_augment.h5
# Epoch 4/50
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.1782e-04 - val_loss: 0.0015
#
# Epoch 00004: val_loss improved from 0.00178 to 0.00152, saving model to best_weights_augment.h5
# Epoch 5/50
# 3424/3424 [==============================] - 28s 8ms/step - loss: 7.1711e-04 - val_loss: 0.0013
#
# Epoch 00005: val_loss improved from 0.00152 to 0.00126, saving model to best_weights_augment.h5
# Epoch 6/50
# 3424/3424 [==============================] - 28s 8ms/step - loss: 5.9550e-04 - val_loss: 0.0011
#
# Epoch 00006: val_loss improved from 0.00126 to 0.00112, saving model to best_weights_augment.h5
# Epoch 7/50
# 3424/3424 [==============================] - 28s 8ms/step - loss: 5.1718e-04 - val_loss: 9.6723e-04
#
# Epoch 00007: val_loss improved from 0.00112 to 0.00097, saving model to best_weights_augment.h5
# Epoch 8/50
# 3424/3424 [==============================] - 28s 8ms/step - loss: 4.5605e-04 - val_loss: 9.0684e-04
#
# Epoch 00008: val_loss improved from 0.00097 to 0.00091, saving model to best_weights_augment.h5
# Epoch 9/50
# 3424/3424 [==============================] - 28s 8ms/step - loss: 4.3073e-04 - val_loss: 8.9668e-04
#
# Epoch 00009: val_loss improved from 0.00091 to 0.00090, saving model to best_weights_augment.h5
# Epoch 10/50
# 3424/3424 [==============================] - 28s 8ms/step - loss: 3.8796e-04 - val_loss: 8.4038e-04
#
# Epoch 00010: val_loss improved from 0.00090 to 0.00084, saving model to best_weights_augment.h5
# Epoch 11/50
# 3424/3424 [==============================] - 28s 8ms/step - loss: 3.5971e-04 - val_loss: 7.9843e-04
#
# Epoch 00011: val_loss improved from 0.00084 to 0.00080, saving model to best_weights_augment.h5
# Epoch 12/50
# 3424/3424 [==============================] - 28s 8ms/step - loss: 3.4593e-04 - val_loss: 7.7890e-04
#
# Epoch 00012: val_loss improved from 0.00080 to 0.00078, saving model to best_weights_augment.h5
# Epoch 13/50
# 3424/3424 [==============================] - 28s 8ms/step - loss: 3.2821e-04 - val_loss: 7.5036e-04
#
# Epoch 00013: val_loss improved from 0.00078 to 0.00075, saving model to best_weights_augment.h5
# Epoch 14/50
# 3424/3424 [==============================] - 28s 8ms/step - loss: 3.1147e-04 - val_loss: 7.3918e-04
#
# Epoch 00014: val_loss improved from 0.00075 to 0.00074, saving model to best_weights_augment.h5
# Epoch 15/50
# 3424/3424 [==============================] - 28s 8ms/step - loss: 2.9690e-04 - val_loss: 7.3009e-04
#
# Epoch 00015: val_loss improved from 0.00074 to 0.00073, saving model to best_weights_augment.h5
# Epoch 16/50
# 3424/3424 [==============================] - 28s 8ms/step - loss: 2.8426e-04 - val_loss: 6.9426e-04
#
# Epoch 00016: val_loss improved from 0.00073 to 0.00069, saving model to best_weights_augment.h5
# Epoch 17/50
# 3424/3424 [==============================] - 28s 8ms/step - loss: 2.7822e-04 - val_loss: 6.9607e-04
#
# Epoch 00017: val_loss did not improve from 0.00069
# Epoch 18/50
# 3424/3424 [==============================] - 31s 9ms/step - loss: 2.6922e-04 - val_loss: 7.1747e-04
#
# Epoch 00018: val_loss did not improve from 0.00069
# Epoch 19/50
# 3424/3424 [==============================] - 28s 8ms/step - loss: 2.5886e-04 - val_loss: 7.1777e-04
#
# Epoch 00019: val_loss did not improve from 0.00069
# Epoch 20/50
# 3424/3424 [==============================] - 28s 8ms/step - loss: 2.4977e-04 - val_loss: 7.0430e-04
#
# Epoch 00020: val_loss did not improve from 0.00069
# Epoch 21/50
# 3424/3424 [==============================] - 28s 8ms/step - loss: 2.4462e-04 - val_loss: 6.8382e-04
#
# Epoch 00021: val_loss improved from 0.00069 to 0.00068, saving model to best_weights_augment.h5
# Epoch 22/50
# 3424/3424 [==============================] - 28s 8ms/step - loss: 2.3608e-04 - val_loss: 6.8350e-04
#
# Epoch 00022: val_loss improved from 0.00068 to 0.00068, saving model to best_weights_augment.h5
# Epoch 23/50
# 3424/3424 [==============================] - 28s 8ms/step - loss: 2.3759e-04 - val_loss: 6.5640e-04
#
# Epoch 00023: val_loss improved from 0.00068 to 0.00066, saving model to best_weights_augment.h5
# Epoch 24/50
# 3424/3424 [==============================] - 28s 8ms/step - loss: 2.2707e-04 - val_loss: 7.0777e-04
#
# Epoch 00024: val_loss did not improve from 0.00066
# Epoch 25/50
# 3424/3424 [==============================] - 28s 8ms/step - loss: 2.2247e-04 - val_loss: 6.4624e-04
#
# Epoch 00025: val_loss improved from 0.00066 to 0.00065, saving model to best_weights_augment.h5
# Epoch 26/50
# 3424/3424 [==============================] - 28s 8ms/step - loss: 2.1316e-04 - val_loss: 7.2115e-04
#
# Epoch 00026: val_loss did not improve from 0.00065
# Epoch 27/50
# 3424/3424 [==============================] - 28s 8ms/step - loss: 2.1285e-04 - val_loss: 6.6956e-04
#
# Epoch 00027: val_loss did not improve from 0.00065
# Epoch 28/50
# 3424/3424 [==============================] - 28s 8ms/step - loss: 2.0591e-04 - val_loss: 6.6090e-04
#
# Epoch 00028: val_loss did not improve from 0.00065
# Epoch 29/50
# 3424/3424 [==============================] - 28s 8ms/step - loss: 2.0373e-04 - val_loss: 6.4556e-04
#
# Epoch 00029: val_loss improved from 0.00065 to 0.00065, saving model to best_weights_augment.h5
# Epoch 30/50
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.9655e-04 - val_loss: 6.5556e-04
#
# Epoch 00030: val_loss did not improve from 0.00065
# Epoch 31/50
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.9502e-04 - val_loss: 6.8104e-04
#
# Epoch 00031: val_loss did not improve from 0.00065
# Epoch 32/50
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.9304e-04 - val_loss: 6.7649e-04
#
# Epoch 00032: val_loss did not improve from 0.00065
# Epoch 33/50
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.8818e-04 - val_loss: 6.6870e-04
#
# Epoch 00033: val_loss did not improve from 0.00065
# Epoch 34/50
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.8216e-04 - val_loss: 6.2732e-04
#
# Epoch 00034: val_loss improved from 0.00065 to 0.00063, saving model to best_weights_augment.h5
# Epoch 35/50
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.7860e-04 - val_loss: 6.6292e-04
#
# Epoch 00035: val_loss did not improve from 0.00063
# Epoch 36/50
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.7749e-04 - val_loss: 6.2505e-04
#
# Epoch 00036: val_loss improved from 0.00063 to 0.00063, saving model to best_weights_augment.h5
# Epoch 37/50
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.7336e-04 - val_loss: 6.2124e-04
#
# Epoch 00037: val_loss improved from 0.00063 to 0.00062, saving model to best_weights_augment.h5
# Epoch 38/50
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.7009e-04 - val_loss: 6.4984e-04
#
# Epoch 00038: val_loss did not improve from 0.00062
# Epoch 39/50
# 3424/3424 [==============================] - 31s 9ms/step - loss: 1.6924e-04 - val_loss: 6.8360e-04
#
# Epoch 00039: val_loss did not improve from 0.00062
# Epoch 40/50
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.6716e-04 - val_loss: 6.4444e-04
#
# Epoch 00040: val_loss did not improve from 0.00062
# Epoch 41/50
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.6266e-04 - val_loss: 6.7418e-04
#
# Epoch 00041: val_loss did not improve from 0.00062
# Epoch 42/50
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.6433e-04 - val_loss: 6.5236e-04
#
# Epoch 00042: val_loss did not improve from 0.00062
# Epoch 43/50
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.6339e-04 - val_loss: 6.4754e-04
#
# Epoch 00043: val_loss did not improve from 0.00062
# Epoch 44/50
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.5516e-04 - val_loss: 6.1113e-04
#
# Epoch 00044: val_loss improved from 0.00062 to 0.00061, saving model to best_weights_augment.h5
# Epoch 45/50
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.5232e-04 - val_loss: 6.5089e-04
#
# Epoch 00045: val_loss did not improve from 0.00061
# Epoch 46/50
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.4941e-04 - val_loss: 6.1295e-04
#
# Epoch 00046: val_loss did not improve from 0.00061
# Epoch 47/50
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.4744e-04 - val_loss: 6.2176e-04
#
# Epoch 00047: val_loss did not improve from 0.00061
# Epoch 48/50
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.5057e-04 - val_loss: 6.2393e-04
#
# Epoch 00048: val_loss did not improve from 0.00061
# Epoch 49/50
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.4627e-04 - val_loss: 6.2494e-04
#
# Epoch 00049: val_loss did not improve from 0.00061
# Epoch 50/50
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.4542e-04 - val_loss: 6.4954e-04
#
# Epoch 00050: val_loss did not improve from 0.00061

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model_aug.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model_aug.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# 增加了左右翻轉以後，應該可以在這個範例中看到 loss 有稍微降一點（可能因為隨機而略有不同），這裡的目的主要還是去體會對原始圖像做 augmentation 以後，也要對原始 label 做合理的調整。
